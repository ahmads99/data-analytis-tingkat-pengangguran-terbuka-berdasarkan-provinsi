# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
pengangguran_df = pd.read_csv('tingkat-pengagguran-prov.csv')
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
pengangguran_df
# Out:
#              38 Provinsi                                         Unnamed: 1  \
# 0                    NaN  Tingkat Pengangguran Terbuka Menurut Provinsi ...
# 1                    NaN                                               2023
# 2                    NaN                                           Februari
# 3                   ACEH                                               5.75
# 4         SUMATERA UTARA                                               5.24
# 5         SUMATERA BARAT                                                5.9
# 6                   RIAU                                               4.25
# 7                  JAMBI                                                4.5
# 8       SUMATERA SELATAN                                               4.53
# 9               BENGKULU                                               3.21
# 10               LAMPUNG                                               4.18
# 11  KEP. BANGKA BELITUNG                                               3.89
# 12             KEP. RIAU                                               7.61
# 13           DKI JAKARTA                                               7.57
# 14            JAWA BARAT                                               7.89
# 15           JAWA TENGAH                                               5.24
# 16         DI YOGYAKARTA                                               3.58
# 17            JAWA TIMUR                                               4.33
# 18                BANTEN                                               7.97
# 19                  BALI                                               3.73
# 20   NUSA TENGGARA BARAT                                               3.73
# 21   NUSA TENGGARA TIMUR                                                3.1
# 22      KALIMANTAN BARAT                                               4.52
# 23     KALIMANTAN TENGAH                                               3.84
# 24    KALIMANTAN SELATAN                                               3.95
# 25      KALIMANTAN TIMUR                                               6.37
# 26      KALIMANTAN UTARA                                                4.1
# 27        SULAWESI UTARA                                               6.19
# 28       SULAWESI TENGAH                                               3.49
# 29      SULAWESI SELATAN                                               5.26
# 30     SULAWESI TENGGARA                                               3.66
# 31             GORONTALO                                               3.07
# 32        SULAWESI BARAT                                               3.04
# 33                MALUKU                                               6.08
# 34          MALUKU UTARA                                                4.6
# 35           PAPUA BARAT                                               5.53
# 36      PAPUA BARAT DAYA                                                  -
# 37                 PAPUA                                               3.49
# 38         PAPUA SELATAN                                                  -
# 39          PAPUA TENGAH                                                  -
# 40      PAPUA PEGUNUNGAN                                                  -
# 41             INDONESIA                                               5.45
#
#    Unnamed: 2
# 0         NaN
# 1         NaN
# 2     Agustus
# 3        6.03
# 4        5.89
# 5        5.94
# 6        4.23
# 7        4.53
# 8        4.11
# 9        3.42
# 10       4.23
# 11       4.56
# 12        6.8
# 13       6.53
# 14       7.44
# 15       5.13
# 16       3.69
# 17       4.88
# 18       7.52
# 19       2.69
# 20        2.8
# 21       3.14
# 22       5.05
# 23        4.1
# 24       4.31
# 25       5.31
# 26       4.01
# 27        6.1
# 28       2.95
# 29       4.33
# 30       3.15
# 31       3.06
# 32       2.27
# 33       6.31
# 34       4.31
# 35       5.38
# 36          -
# 37       2.67
# 38          -
# 39          -
# 40          -
# 41       5.32

# %%
pengangguran_df = pd.read_csv('tingkat-pengagguran-prov.csv')

# Melihat nama kolom
print(pengangguran_df.columns)
# Out:
# Index(['38 Provinsi', 'Unnamed: 1', 'Unnamed: 2'], dtype='object')

# %%
pengangguran_df.columns = ['Provinsi','Februari', 'Agustus']
print(pengangguran_df.head())
# Out:
#          Provinsi                                           Februari  Agustus
# 0             NaN  Tingkat Pengangguran Terbuka Menurut Provinsi ...      NaN
# 1             NaN                                               2023      NaN
# 2             NaN                                           Februari  Agustus
# 3            ACEH                                               5.75     6.03
# 4  SUMATERA UTARA                                               5.24     5.89

# %%
pengangguran_df.head(50)
# Out:
#                 Provinsi                                           Februari  \
# 0                    NaN  Tingkat Pengangguran Terbuka Menurut Provinsi ...
# 1                    NaN                                               2023
# 2                    NaN                                           Februari
# 3                   ACEH                                               5.75
# 4         SUMATERA UTARA                                               5.24
# 5         SUMATERA BARAT                                                5.9
# 6                   RIAU                                               4.25
# 7                  JAMBI                                                4.5
# 8       SUMATERA SELATAN                                               4.53
# 9               BENGKULU                                               3.21
# 10               LAMPUNG                                               4.18
# 11  KEP. BANGKA BELITUNG                                               3.89
# 12             KEP. RIAU                                               7.61
# 13           DKI JAKARTA                                               7.57
# 14            JAWA BARAT                                               7.89
# 15           JAWA TENGAH                                               5.24
# 16         DI YOGYAKARTA                                               3.58
# 17            JAWA TIMUR                                               4.33
# 18                BANTEN                                               7.97
# 19                  BALI                                               3.73
# 20   NUSA TENGGARA BARAT                                               3.73
# 21   NUSA TENGGARA TIMUR                                                3.1
# 22      KALIMANTAN BARAT                                               4.52
# 23     KALIMANTAN TENGAH                                               3.84
# 24    KALIMANTAN SELATAN                                               3.95
# 25      KALIMANTAN TIMUR                                               6.37
# 26      KALIMANTAN UTARA                                                4.1
# 27        SULAWESI UTARA                                               6.19
# 28       SULAWESI TENGAH                                               3.49
# 29      SULAWESI SELATAN                                               5.26
# 30     SULAWESI TENGGARA                                               3.66
# 31             GORONTALO                                               3.07
# 32        SULAWESI BARAT                                               3.04
# 33                MALUKU                                               6.08
# 34          MALUKU UTARA                                                4.6
# 35           PAPUA BARAT                                               5.53
# 36      PAPUA BARAT DAYA                                                  -
# 37                 PAPUA                                               3.49
# 38         PAPUA SELATAN                                                  -
# 39          PAPUA TENGAH                                                  -
# 40      PAPUA PEGUNUNGAN                                                  -
# 41             INDONESIA                                               5.45
#
#     Agustus
# 0       NaN
# 1       NaN
# 2   Agustus
# 3      6.03
# 4      5.89
# 5      5.94
# 6      4.23
# 7      4.53
# 8      4.11
# 9      3.42
# 10     4.23
# 11     4.56
# 12      6.8
# 13     6.53
# 14     7.44
# 15     5.13
# 16     3.69
# 17     4.88
# 18     7.52
# 19     2.69
# 20      2.8
# 21     3.14
# 22     5.05
# 23      4.1
# 24     4.31
# 25     5.31
# 26     4.01
# 27      6.1
# 28     2.95
# 29     4.33
# 30     3.15
# 31     3.06
# 32     2.27
# 33     6.31
# 34     4.31
# 35     5.38
# 36        -
# 37     2.67
# 38        -
# 39        -
# 40        -
# 41     5.32

# %%
pengangguran_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 42 entries, 0 to 41
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Provinsi  39 non-null     object
#  1   Februari  42 non-null     object
#  2   Agustus   40 non-null     object
# dtypes: object(3)
# memory usage: 1.1+ KB

# %%
pengangguran_df.isna().sum()
# Out:
# Provinsi    3
# Februari    0
# Agustus     2
# dtype: int64

# %%
print("Jumlah duplikasi: ", pengangguran_df.duplicated().sum())
# Out:
# Jumlah duplikasi:  0

# %%
pengangguran_df.describe()
# Out:
#        Provinsi Februari Agustus
# count        39       42      40
# unique       39       36      35
# top        ACEH        -       -
# freq          1        4       4

# %%
pengangguran_df.drop_duplicates(inplace=True)

# %%
print("Jumlah duplikasi: ", pengangguran_df.duplicated().sum())
# Out:
# Jumlah duplikasi:  0

# %%
pengangguran_df[pengangguran_df.Provinsi.isna()]
# Out:
#   Provinsi                                           Februari  Agustus
# 0      NaN  Tingkat Pengangguran Terbuka Menurut Provinsi ...      NaN
# 1      NaN                                               2023      NaN
# 2      NaN                                           Februari  Agustus

# %%
pengangguran_df.Provinsi.value_counts()
# Out:
# Provinsi
# ACEH                    1
# SULAWESI BARAT          1
# KALIMANTAN TIMUR        1
# KALIMANTAN UTARA        1
# SULAWESI UTARA          1
# SULAWESI TENGAH         1
# SULAWESI SELATAN        1
# SULAWESI TENGGARA       1
# GORONTALO               1
# MALUKU                  1
# KALIMANTAN TENGAH       1
# MALUKU UTARA            1
# PAPUA BARAT             1
# PAPUA BARAT DAYA        1
# PAPUA                   1
# PAPUA SELATAN           1
# PAPUA TENGAH            1
# PAPUA PEGUNUNGAN        1
# KALIMANTAN SELATAN      1
# KALIMANTAN BARAT        1
# SUMATERA UTARA          1
# KEP. RIAU               1
# SUMATERA BARAT          1
# RIAU                    1
# JAMBI                   1
# SUMATERA SELATAN        1
# BENGKULU                1
# LAMPUNG                 1
# KEP. BANGKA BELITUNG    1
# DKI JAKARTA             1
# NUSA TENGGARA TIMUR     1
# JAWA BARAT              1
# JAWA TENGAH             1
# DI YOGYAKARTA           1
# JAWA TIMUR              1
# BANTEN                  1
# BALI                    1
# NUSA TENGGARA BARAT     1
# INDONESIA               1
# Name: count, dtype: int64

# %%
pengangguran_df = pengangguran_df.dropna(subset=['Provinsi', 'Februari', 'Agustus'])

# %%
pengangguran_df.head(50)
# Out:
#                 Provinsi Februari Agustus
# 3                   ACEH     5.75    6.03
# 4         SUMATERA UTARA     5.24    5.89
# 5         SUMATERA BARAT      5.9    5.94
# 6                   RIAU     4.25    4.23
# 7                  JAMBI      4.5    4.53
# 8       SUMATERA SELATAN     4.53    4.11
# 9               BENGKULU     3.21    3.42
# 10               LAMPUNG     4.18    4.23
# 11  KEP. BANGKA BELITUNG     3.89    4.56
# 12             KEP. RIAU     7.61     6.8
# 13           DKI JAKARTA     7.57    6.53
# 14            JAWA BARAT     7.89    7.44
# 15           JAWA TENGAH     5.24    5.13
# 16         DI YOGYAKARTA     3.58    3.69
# 17            JAWA TIMUR     4.33    4.88
# 18                BANTEN     7.97    7.52
# 19                  BALI     3.73    2.69
# 20   NUSA TENGGARA BARAT     3.73     2.8
# 21   NUSA TENGGARA TIMUR      3.1    3.14
# 22      KALIMANTAN BARAT     4.52    5.05
# 23     KALIMANTAN TENGAH     3.84     4.1
# 24    KALIMANTAN SELATAN     3.95    4.31
# 25      KALIMANTAN TIMUR     6.37    5.31
# 26      KALIMANTAN UTARA      4.1    4.01
# 27        SULAWESI UTARA     6.19     6.1
# 28       SULAWESI TENGAH     3.49    2.95
# 29      SULAWESI SELATAN     5.26    4.33
# 30     SULAWESI TENGGARA     3.66    3.15
# 31             GORONTALO     3.07    3.06
# 32        SULAWESI BARAT     3.04    2.27
# 33                MALUKU     6.08    6.31
# 34          MALUKU UTARA      4.6    4.31
# 35           PAPUA BARAT     5.53    5.38
# 36      PAPUA BARAT DAYA        -       -
# 37                 PAPUA     3.49    2.67
# 38         PAPUA SELATAN        -       -
# 39          PAPUA TENGAH        -       -
# 40      PAPUA PEGUNUNGAN        -       -
# 41             INDONESIA     5.45    5.32

# %%
pengangguran_df = pengangguran_df.reset_index(drop=True) # Correct the variable name from 'penggangguran_df' to 'pengangguran_df'

# %%
pengangguran_df.head(50)
# Out:
#                 Provinsi Februari Agustus
# 0                   ACEH     5.75    6.03
# 1         SUMATERA UTARA     5.24    5.89
# 2         SUMATERA BARAT      5.9    5.94
# 3                   RIAU     4.25    4.23
# 4                  JAMBI      4.5    4.53
# 5       SUMATERA SELATAN     4.53    4.11
# 6               BENGKULU     3.21    3.42
# 7                LAMPUNG     4.18    4.23
# 8   KEP. BANGKA BELITUNG     3.89    4.56
# 9              KEP. RIAU     7.61     6.8
# 10           DKI JAKARTA     7.57    6.53
# 11            JAWA BARAT     7.89    7.44
# 12           JAWA TENGAH     5.24    5.13
# 13         DI YOGYAKARTA     3.58    3.69
# 14            JAWA TIMUR     4.33    4.88
# 15                BANTEN     7.97    7.52
# 16                  BALI     3.73    2.69
# 17   NUSA TENGGARA BARAT     3.73     2.8
# 18   NUSA TENGGARA TIMUR      3.1    3.14
# 19      KALIMANTAN BARAT     4.52    5.05
# 20     KALIMANTAN TENGAH     3.84     4.1
# 21    KALIMANTAN SELATAN     3.95    4.31
# 22      KALIMANTAN TIMUR     6.37    5.31
# 23      KALIMANTAN UTARA      4.1    4.01
# 24        SULAWESI UTARA     6.19     6.1
# 25       SULAWESI TENGAH     3.49    2.95
# 26      SULAWESI SELATAN     5.26    4.33
# 27     SULAWESI TENGGARA     3.66    3.15
# 28             GORONTALO     3.07    3.06
# 29        SULAWESI BARAT     3.04    2.27
# 30                MALUKU     6.08    6.31
# 31          MALUKU UTARA      4.6    4.31
# 32           PAPUA BARAT     5.53    5.38
# 33      PAPUA BARAT DAYA        -       -
# 34                 PAPUA     3.49    2.67
# 35         PAPUA SELATAN        -       -
# 36          PAPUA TENGAH        -       -
# 37      PAPUA PEGUNUNGAN        -       -
# 38             INDONESIA     5.45    5.32

# %%
pengangguran_df.replace('-', '0', inplace=True)
pengangguran_df[['Februari', 'Agustus']] = pengangguran_df[['Februari', 'Agustus']].astype(float)

# %%
# Menampilkan DataFrame untuk memastikan
print(pengangguran_df.head(50))
# Out:
#                 Provinsi  Februari  Agustus
# 0                   ACEH      5.75     6.03
# 1         SUMATERA UTARA      5.24     5.89
# 2         SUMATERA BARAT      5.90     5.94
# 3                   RIAU      4.25     4.23
# 4                  JAMBI      4.50     4.53
# 5       SUMATERA SELATAN      4.53     4.11
# 6               BENGKULU      3.21     3.42
# 7                LAMPUNG      4.18     4.23
# 8   KEP. BANGKA BELITUNG      3.89     4.56
# 9              KEP. RIAU      7.61     6.80
# 10           DKI JAKARTA      7.57     6.53
# 11            JAWA BARAT      7.89     7.44
# 12           JAWA TENGAH      5.24     5.13
# 13         DI YOGYAKARTA      3.58     3.69
# 14            JAWA TIMUR      4.33     4.88
# 15                BANTEN      7.97     7.52
# 16                  BALI      3.73     2.69
# 17   NUSA TENGGARA BARAT      3.73     2.80
# 18   NUSA TENGGARA TIMUR      3.10     3.14
# 19      KALIMANTAN BARAT      4.52     5.05
# 20     KALIMANTAN TENGAH      3.84     4.10
# 21    KALIMANTAN SELATAN      3.95     4.31
# 22      KALIMANTAN TIMUR      6.37     5.31
# 23      KALIMANTAN UTARA      4.10     4.01
# 24        SULAWESI UTARA      6.19     6.10
# 25       SULAWESI TENGAH      3.49     2.95
# 26      SULAWESI SELATAN      5.26     4.33
# 27     SULAWESI TENGGARA      3.66     3.15
# 28             GORONTALO      3.07     3.06
# 29        SULAWESI BARAT      3.04     2.27
# 30                MALUKU      6.08     6.31
# 31          MALUKU UTARA      4.60     4.31
# 32           PAPUA BARAT      5.53     5.38
# 33      PAPUA BARAT DAYA      0.00     0.00
# 34                 PAPUA      3.49     2.67
# 35         PAPUA SELATAN      0.00     0.00
# 36          PAPUA TENGAH      0.00     0.00
# 37      PAPUA PEGUNUNGAN      0.00     0.00
# 38             INDONESIA      5.45     5.32

# %%
pengangguran_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 39 entries, 0 to 38
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Provinsi  39 non-null     object
#  1   Februari  39 non-null     float64
#  2   Agustus   39 non-null     float64
# dtypes: float64(2), object(1)
# memory usage: 1.0+ KB

# %%
pengangguran_df.head(50)
# Out:
#                 Provinsi  Februari  Agustus
# 0                   ACEH      5.75     6.03
# 1         SUMATERA UTARA      5.24     5.89
# 2         SUMATERA BARAT      5.90     5.94
# 3                   RIAU      4.25     4.23
# 4                  JAMBI      4.50     4.53
# 5       SUMATERA SELATAN      4.53     4.11
# 6               BENGKULU      3.21     3.42
# 7                LAMPUNG      4.18     4.23
# 8   KEP. BANGKA BELITUNG      3.89     4.56
# 9              KEP. RIAU      7.61     6.80
# 10           DKI JAKARTA      7.57     6.53
# 11            JAWA BARAT      7.89     7.44
# 12           JAWA TENGAH      5.24     5.13
# 13         DI YOGYAKARTA      3.58     3.69
# 14            JAWA TIMUR      4.33     4.88
# 15                BANTEN      7.97     7.52
# 16                  BALI      3.73     2.69
# 17   NUSA TENGGARA BARAT      3.73     2.80
# 18   NUSA TENGGARA TIMUR      3.10     3.14
# 19      KALIMANTAN BARAT      4.52     5.05
# 20     KALIMANTAN TENGAH      3.84     4.10
# 21    KALIMANTAN SELATAN      3.95     4.31
# 22      KALIMANTAN TIMUR      6.37     5.31
# 23      KALIMANTAN UTARA      4.10     4.01
# 24        SULAWESI UTARA      6.19     6.10
# 25       SULAWESI TENGAH      3.49     2.95
# 26      SULAWESI SELATAN      5.26     4.33
# 27     SULAWESI TENGGARA      3.66     3.15
# 28             GORONTALO      3.07     3.06
# 29        SULAWESI BARAT      3.04     2.27
# 30                MALUKU      6.08     6.31
# 31          MALUKU UTARA      4.60     4.31
# 32           PAPUA BARAT      5.53     5.38
# 33      PAPUA BARAT DAYA      0.00     0.00
# 34                 PAPUA      3.49     2.67
# 35         PAPUA SELATAN      0.00     0.00
# 36          PAPUA TENGAH      0.00     0.00
# 37      PAPUA PEGUNUNGAN      0.00     0.00
# 38             INDONESIA      5.45     5.32

# %%
import pandas as pd # Import the pandas library

Provinsi_columns = ["Provinsi"]

for column in Provinsi_columns:
  pengangguran_df[column] = pengangguran_df[column].astype(str) # Use astype(str) for string conversion

# %%
pengangguran_df.describe()
# Out:
#         Februari    Agustus
# count  39.000000  39.000000
# mean    4.329231   4.158718
# std     2.003646   1.946820
# min     0.000000   0.000000
# 25%     3.535000   3.100000
# 50%     4.250000   4.310000
# 75%     5.490000   5.350000
# max     7.970000   7.520000

# %%
pengangguran_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 39 entries, 0 to 38
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Provinsi  39 non-null     object
#  1   Februari  39 non-null     float64
#  2   Agustus   39 non-null     float64
# dtypes: float64(2), object(1)
# memory usage: 1.0+ KB

# %%
print("Jumlah duplikasi: ", pengangguran_df.duplicated().sum())
# Out:
# Jumlah duplikasi:  0

# %%
pengangguran_df.isna().sum()
# Out:
# Provinsi    0
# Februari    0
# Agustus     0
# dtype: int64

# %%
pengangguran_df.describe()
# Out:
#         Februari    Agustus
# count  39.000000  39.000000
# mean    4.329231   4.158718
# std     2.003646   1.946820
# min     0.000000   0.000000
# 25%     3.535000   3.100000
# 50%     4.250000   4.310000
# 75%     5.490000   5.350000
# max     7.970000   7.520000

# %%
pengangguran_df.describe(include="all")
# Out:
#        Provinsi   Februari    Agustus
# count        39  39.000000  39.000000
# unique       39        NaN        NaN
# top        ACEH        NaN        NaN
# freq          1        NaN        NaN
# mean        NaN   4.329231   4.158718
# std         NaN   2.003646   1.946820
# min         NaN   0.000000   0.000000
# 25%         NaN   3.535000   3.100000
# 50%         NaN   4.250000   4.310000
# 75%         NaN   5.490000   5.350000
# max         NaN   7.970000   7.520000

# %%
pengangguran_df.head(50)
# Out:
#                 Provinsi  Februari  Agustus
# 0                   ACEH      5.75     6.03
# 1         SUMATERA UTARA      5.24     5.89
# 2         SUMATERA BARAT      5.90     5.94
# 3                   RIAU      4.25     4.23
# 4                  JAMBI      4.50     4.53
# 5       SUMATERA SELATAN      4.53     4.11
# 6               BENGKULU      3.21     3.42
# 7                LAMPUNG      4.18     4.23
# 8   KEP. BANGKA BELITUNG      3.89     4.56
# 9              KEP. RIAU      7.61     6.80
# 10           DKI JAKARTA      7.57     6.53
# 11            JAWA BARAT      7.89     7.44
# 12           JAWA TENGAH      5.24     5.13
# 13         DI YOGYAKARTA      3.58     3.69
# 14            JAWA TIMUR      4.33     4.88
# 15                BANTEN      7.97     7.52
# 16                  BALI      3.73     2.69
# 17   NUSA TENGGARA BARAT      3.73     2.80
# 18   NUSA TENGGARA TIMUR      3.10     3.14
# 19      KALIMANTAN BARAT      4.52     5.05
# 20     KALIMANTAN TENGAH      3.84     4.10
# 21    KALIMANTAN SELATAN      3.95     4.31
# 22      KALIMANTAN TIMUR      6.37     5.31
# 23      KALIMANTAN UTARA      4.10     4.01
# 24        SULAWESI UTARA      6.19     6.10
# 25       SULAWESI TENGAH      3.49     2.95
# 26      SULAWESI SELATAN      5.26     4.33
# 27     SULAWESI TENGGARA      3.66     3.15
# 28             GORONTALO      3.07     3.06
# 29        SULAWESI BARAT      3.04     2.27
# 30                MALUKU      6.08     6.31
# 31          MALUKU UTARA      4.60     4.31
# 32           PAPUA BARAT      5.53     5.38
# 33      PAPUA BARAT DAYA      0.00     0.00
# 34                 PAPUA      3.49     2.67
# 35         PAPUA SELATAN      0.00     0.00
# 36          PAPUA TENGAH      0.00     0.00
# 37      PAPUA PEGUNUNGAN      0.00     0.00
# 38             INDONESIA      5.45     5.32

# %%
# Menghitung total tingkat pengangguran per provinsi
pengangguran_df["total_tingkat"] = pengangguran_df["Februari"] + pengangguran_df["Agustus"]

# Menampilkan DataFrame yang telah diperbarui
print(pengangguran_df)
# Out:
#                 Provinsi  Februari  Agustus  total_tingkat
# 0                   ACEH      5.75     6.03          11.78
# 1         SUMATERA UTARA      5.24     5.89          11.13
# 2         SUMATERA BARAT      5.90     5.94          11.84
# 3                   RIAU      4.25     4.23           8.48
# 4                  JAMBI      4.50     4.53           9.03
# 5       SUMATERA SELATAN      4.53     4.11           8.64
# 6               BENGKULU      3.21     3.42           6.63
# 7                LAMPUNG      4.18     4.23           8.41
# 8   KEP. BANGKA BELITUNG      3.89     4.56           8.45
# 9              KEP. RIAU      7.61     6.80          14.41
# 10           DKI JAKARTA      7.57     6.53          14.10
# 11            JAWA BARAT      7.89     7.44          15.33
# 12           JAWA TENGAH      5.24     5.13          10.37
# 13         DI YOGYAKARTA      3.58     3.69           7.27
# 14            JAWA TIMUR      4.33     4.88           9.21
# 15                BANTEN      7.97     7.52          15.49
# 16                  BALI      3.73     2.69           6.42
# 17   NUSA TENGGARA BARAT      3.73     2.80           6.53
# 18   NUSA TENGGARA TIMUR      3.10     3.14           6.24
# 19      KALIMANTAN BARAT      4.52     5.05           9.57
# 20     KALIMANTAN TENGAH      3.84     4.10           7.94
# 21    KALIMANTAN SELATAN      3.95     4.31           8.26
# 22      KALIMANTAN TIMUR      6.37     5.31          11.68
# 23      KALIMANTAN UTARA      4.10     4.01           8.11
# 24        SULAWESI UTARA      6.19     6.10          12.29
# 25       SULAWESI TENGAH      3.49     2.95           6.44
# 26      SULAWESI SELATAN      5.26     4.33           9.59
# 27     SULAWESI TENGGARA      3.66     3.15           6.81
# 28             GORONTALO      3.07     3.06           6.13
# 29        SULAWESI BARAT      3.04     2.27           5.31
# 30                MALUKU      6.08     6.31          12.39
# 31          MALUKU UTARA      4.60     4.31           8.91
# 32           PAPUA BARAT      5.53     5.38          10.91
# 33      PAPUA BARAT DAYA      0.00     0.00           0.00
# 34                 PAPUA      3.49     2.67           6.16
# 35         PAPUA SELATAN      0.00     0.00           0.00
# 36          PAPUA TENGAH      0.00     0.00           0.00
# 37      PAPUA PEGUNUNGAN      0.00     0.00           0.00
# 38             INDONESIA      5.45     5.32          10.77

# %%
pengangguran_df.describe(include="all")
# Out:
#        Provinsi   Februari    Agustus  total_tingkat
# count        39  39.000000  39.000000      39.000000
# unique       39        NaN        NaN            NaN
# top        ACEH        NaN        NaN            NaN
# freq          1        NaN        NaN            NaN
# mean        NaN   4.329231   4.158718       8.487949
# std         NaN   2.003646   1.946820       3.921002
# min         NaN   0.000000   0.000000       0.000000
# 25%         NaN   3.535000   3.100000       6.485000
# 50%         NaN   4.250000   4.310000       8.480000
# 75%         NaN   5.490000   5.350000      11.020000
# max         NaN   7.970000   7.520000      15.490000

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Menghitung rata-rata tingkat pengangguran per provinsi
mean_unemployment = pengangguran_df.groupby('Provinsi')[['Februari', 'Agustus']].mean().reset_index()

# Menambahkan kolom Total
mean_unemployment['Total'] = mean_unemployment['Februari'] + mean_unemployment['Agustus']

# Visualisasi rata-rata tingkat pengangguran Februari per provinsi
plt.figure(figsize=(14, 7))
sns.barplot(x='Provinsi', y='Februari', data=mean_unemployment, palette='viridis')
plt.title('Rata-rata Tingkat Pengangguran Februari per Provinsi')
plt.xticks(rotation=90)
plt.xlabel('Provinsi')
plt.ylabel('Rata-rata Tingkat Pengangguran (%)')
plt.show()

# Visualisasi rata-rata tingkat pengangguran Agustus per provinsi
plt.figure(figsize=(14, 7))
sns.barplot(x='Provinsi', y='Agustus', data=mean_unemployment, palette='viridis')
plt.title('Rata-rata Tingkat Pengangguran Agustus per Provinsi')
plt.xticks(rotation=90)
plt.xlabel('Provinsi')
plt.ylabel('Rata-rata Tingkat Pengangguran (%)')
plt.show()

# Visualisasi total tingkat pengangguran per provinsi
plt.figure(figsize=(14, 7))
sns.barplot(x='Provinsi', y='Total', data=mean_unemployment, palette='viridis')
plt.title('Total Tingkat Pengangguran per Provinsi')
plt.xticks(rotation=90)
plt.xlabel('Provinsi')
plt.ylabel('Total Tingkat Pengangguran (%)')
plt.show()
# Out:
# <ipython-input-366-4cd21268c38e>:12: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Provinsi', y='Februari', data=mean_unemployment, palette='viridis')
# <ipython-input-366-4cd21268c38e>:21: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Provinsi', y='Agustus', data=mean_unemployment, palette='viridis')
# <ipython-input-366-4cd21268c38e>:30: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Provinsi', y='Total', data=mean_unemployment, palette='viridis')

# %%
# Select only the numeric columns for correlation calculation
numeric_df = pengangguran_df[['Februari', 'Agustus']]

# Calculate the correlation matrix
correlation = numeric_df.corr()

# Print the correlation matrix
print(correlation)

# Visualize the correlation heatmap
plt.figure(figsize=(8, 6))
sns.heatmap(correlation, annot=True, cmap='coolwarm', fmt='.2f')
plt.title('Heatmap Korelasi Antar Kolom')
plt.show()
# Out:
#           Februari   Agustus
# Februari  1.000000  0.970273
# Agustus   0.970273  1.000000

# %%
plt.figure(figsize=(16, 6))
sns.barplot(x='Provinsi', y='total_tingkat', data=pengangguran_df, palette='viridis')
plt.title('Total Tingkat Pengangguran Per Provinsi')
plt.xticks(rotation=90)
plt.xlabel('Provinsi')
plt.ylabel('Total Tingkat Pengangguran')
plt.show()
# Out:
# <ipython-input-379-f6af3f1d495c>:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Provinsi', y='total_tingkat', data=pengangguran_df, palette='viridis')

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(14, 8))  # Ukuran yang lebih besar untuk tampilan yang lebih baik
sns.scatterplot(x='Februari', y='Agustus', hue='Provinsi', data=pengangguran_df, palette='tab10', s=100, edgecolor='w')

plt.title('Tingkat Pengangguran Februari vs Agustus Per Provinsi', fontsize=16)
plt.xlabel('Tingkat Pengangguran Februari', fontsize=14)
plt.ylabel('Tingkat Pengangguran Agustus', fontsize=14)
plt.legend(title='Provinsi', bbox_to_anchor=(1.05, 1), loc='upper left', fontsize=12)
plt.grid(True, linestyle='--', alpha=0.7)
plt.tight_layout()  # Mengatur layout agar tidak ada elemen yang terpotong
plt.show()

# %%
plt.figure(figsize=(18, 8))
bar_plot = sns.barplot(x='Provinsi', y='total_tingkat', data=pengangguran_df, palette='viridis')
plt.title('Total Tingkat Pengangguran Per Provinsi')
plt.xticks(rotation=90)
plt.xlabel('Provinsi')
plt.ylabel('Total Tingkat Pengangguran')

# Menambahkan label pada bar
for p in bar_plot.patches:
    bar_plot.annotate(format(p.get_height(), '.2f'),
                      (p.get_x() + p.get_width() / 2., p.get_height()),
                      ha='center', va='center',
                      xytext=(0, 9),
                      textcoords='offset points')

plt.show()
# Out:
# <ipython-input-389-5c9e41250622>:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   bar_plot = sns.barplot(x='Provinsi', y='total_tingkat', data=pengangguran_df, palette='viridis')

# %%
# Assuming 'pengangguran_df' is your DataFrame containing all the data
pengangguran_df.to_csv("all_data_tingkatpeng.csv", index=False)

# %%
from google.colab import files

# Mengunggah file CSV yang telah dibuat
files.download("all_data_tingkatpeng.csv")
